# %% [markdown]
# <a href="https://colab.research.google.com/github/MariumRamisa/capstone_ob_detection_model/blob/main/cocodataset_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 31.1/201.2 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="GwdSYNkJbqDnKsiSDfdk")
project = rf.workspace("wawrzyniec-mokrogulski").project("coco-olaix")
dataset = project.version(2).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.11, to fix: `pip install ultralytics==8.0.196`

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= /content/drive/MyDrive/trash/data.yaml epochs=100 imgsz=640 save=True
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...
